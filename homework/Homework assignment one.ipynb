# %% [markdown]
# # Homework Assignment Number One

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Section 1: Police killings

# %%
killings = pd.read_csv('../data/police-killings.csv', encoding='cp1252', index_col=[0])
killings.head()
# Out:
#                  name  age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington   16   Male            Black  February   23  2015
# 1      Aaron Rutledge   27   Male            White     April    2  2015
# 2         Aaron Siler   26   Male            White     March   14  2015
# 3        Aaron Valdez   25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic   29   Male            White     March   19  2015
#
#             streetaddress          city state  \
# 0            Clearview Ln     Millbrook    AL
# 1  300 block Iris Park Dr     Pineville    LA
# 2    22nd Ave and 56th St       Kenosha    WI
# 3       3000 Seminole Ave    South Gate    CA
# 4          364 Hiwood Ave  Munroe Falls    OH
#
#               lawenforcementagency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# 1  Rapides Parish Sheriff's Office  Gunshot       No          40930
# ...

# %% [markdown]
# ### 1. Make the following changes to column names:
#
# - lawenforcementagency -> agency
# - raceethnicity -> race

# %%
killings.rename(columns={"lawenforcementagency": "agency", "raceethnicity": "race"}, inplace = True)

# %%
killings.head()
# Out:
#                  name  age gender             race     month  day  year  \
# 0  A'donte Washington   16   Male            Black  February   23  2015
# 1      Aaron Rutledge   27   Male            White     April    2  2015
# 2         Aaron Siler   26   Male            White     March   14  2015
# 3        Aaron Valdez   25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic   29   Male            White     March   19  2015
#
#             streetaddress          city state  \
# 0            Clearview Ln     Millbrook    AL
# 1  300 block Iris Park Dr     Pineville    LA
# 2    22nd Ave and 56th St       Kenosha    WI
# 3       3000 Seminole Ave    South Gate    CA
# 4          364 Hiwood Ave  Munroe Falls    OH
#
#                             agency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# 1  Rapides Parish Sheriff's Office  Gunshot       No          40930
# ...

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
killings.isnull().sum()
# Out:
# name             0
# age              0
# gender           0
# race             0
# month            0
# day              0
# year             0
# streetaddress    4
# city             0
# state            0
# agency           0
# cause            0
# armed            0
# county_income    0
# dtype: int64

# %% [markdown]
# ### 3. Replace each null value in the dataframe with the string "unknown"

# %%
killings.fillna("unknown")
# Out:
#                         name  age  gender             race     month  day  \
# 0         A'donte Washington   16    Male            Black  February   23
# 1             Aaron Rutledge   27    Male            White     April    2
# 2                Aaron Siler   26    Male            White     March   14
# 3               Aaron Valdez   25    Male  Hispanic/Latino     March   11
# 4               Adam Jovicic   29    Male            White     March   19
# 5              Adam Reinhart   29    Male            White     March    7
# 6           Adrian Hernandez   22    Male  Hispanic/Latino     March   27
# 7               Adrian Solis   35    Male  Hispanic/Latino     March   26
# 8              Alan Alverson   44    Male            White   January   28
# 9                 Alan James   31    Male            White  February    7
# 10          Albert Hanson Jr   76    Male            White     April   26
# 11            Alec Ouzounian   40    Male            White       May   12
# ...

# %% [markdown]
# ### 4. How many killings were there in March and April?

# %%
killings.month.value_counts()
# Out:
# March       114
# April        96
# January      90
# February     84
# May          81
# June          2
# Name: month, dtype: int64

# %%
killings.month.value_counts()["April"] + killings.month.value_counts()["March"]
# Out:
# 210

# %% [markdown]
# ### 5. How many male and how many female victims are there?

# %%
killings.gender.value_counts()
# Out:
# Male      445
# Female     22
# Name: gender, dtype: int64

# %% [markdown]
# ### 6. How many killings were of unarmed people?

# %%
#How many people were killed by which means? 
killings.armed.value_counts()
# Out:
# Firearm               230
# No                    102
# Knife                  68
# Other                  26
# Vehicle                18
# Non-lethal firearm     14
# Unknown                 7
# Disputed                2
# Name: armed, dtype: int64

# %%
killings.armed.value_counts()["No"]+ killings.armed.value_counts()["Vehicle"]
# Out:
# 120

# %% [markdown]
# ### 7. What percentage of all killings were unarmed?

# %%
killings.armed.value_counts(normalize=True)["No"]+ killings.armed.value_counts(normalize=True)["Vehicle"]
# Out:
# 0.2569593147751606

# %% [markdown]
# ### 8. What are the 5 states with the most killings?

# %%
#Group by state
killings.groupby("state")

# %%
state = killings.state

# %%
state.value_counts().index.tolist()[:5]
# Out:
# ['CA', 'TX', 'FL', 'AZ', 'OK']

# %%
state.value_counts().head()
# Out:
# CA    74
# TX    46
# FL    29
# AZ    25
# OK    22
# Name: state, dtype: int64

# %% [markdown]
# ### 9. Show a value counts of deaths for each race

# %%
killings.race.value_counts()
# Out:
# White                     236
# Black                     135
# Hispanic/Latino            67
# Unknown                    15
# Asian/Pacific Islander     10
# Native American             4
# Name: race, dtype: int64

# %% [markdown]
# ### 10. Display a histogram of ages of all killings

# %%
killings.age.plot(kind = "hist")

# %% [markdown]
# ### 11. Show histogram of ages for each race

# %%
killings.groupby("race")["age"].mean().plot(kind = "bar", figsize = (10, 8), title = "Average ages for each race")

# %% [markdown]
# ### 12. What is the average age of death by race?

# %%
killings.groupby("race")["age"].mean()
# Out:
# race
# Asian/Pacific Islander    40.800000
# Black                     34.044444
# Hispanic/Latino           31.716418
# Native American           27.750000
# Unknown                   43.533333
# White                     40.466102
# Name: age, dtype: float64

# %% [markdown]
# ### 13. Show a bar chart with counts of deaths every month

# %%
type_month = killings.month.value_counts()
type_month.plot(kind = "bar", figsize = (10, 8), color = "b", title = "Total deaths every month")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Section 2: College Majors

# %%
majors = pd.read_csv('../data/college-majors.csv', index_col=[0])
majors.head()
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %% [markdown]
# ### 1. Delete the columns (employed_full_time_year_round, major_code)

# %%
majors.drop("Employed_full_time_year_round", axis = 1, inplace = True)

# %%
majors.drop("Major_code", axis = 1, inplace = True)

# %%
majors.head()
# Out:
#                                    Major                   Major_category  \
# 0                    GENERAL AGRICULTURE  Agriculture & Natural Resources
# 1  AGRICULTURE PRODUCTION AND MANAGEMENT  Agriculture & Natural Resources
# 2                 AGRICULTURAL ECONOMICS  Agriculture & Natural Resources
# 3                        ANIMAL SCIENCES  Agriculture & Natural Resources
# 4                           FOOD SCIENCE  Agriculture & Natural Resources
#
#     Total  Employed  Unemployed  Unemployment_rate  Median  P25th    P75th
# 0  128148     90245        2423           0.026147   50000  34000  80000.0
# 1   95326     76865        2266           0.028636   54000  36000  80000.0
# 2   33955     26321         821           0.030248   63000  40000  98000.0
# 3  103549     81177        3619           0.042679   46000  30000  72000.0
# 4   24280     17281         894           0.049188   62000  38500  90000.0

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
majors.isnull().sum()
# Out:
# Major                0
# Major_category       0
# Total                0
# Employed             0
# Unemployed           0
# Unemployment_rate    0
# Median               0
# P25th                0
# P75th                0
# dtype: int64

# %% [markdown]
# ### 3. What are the top 10 highest paying majors?

# %%
majors.sort_values(by="P75th", ascending=False).Major.tolist()[:10]
# Out:
# ['PETROLEUM ENGINEERING',
#  'MATHEMATICS AND COMPUTER SCIENCE',
#  'NUCLEAR ENGINEERING',
#  'PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTRATION',
#  'GEOLOGICAL AND GEOPHYSICAL ENGINEERING',
#  'NAVAL ARCHITECTURE AND MARINE ENGINEERING',
#  'MINING AND MINERAL ENGINEERING',
#  'METALLURGICAL ENGINEERING',
#  'CHEMICAL ENGINEERING',
#  'ELECTRICAL ENGINEERING']

# %%
top_payingmajors =majors.sort_values(by="P75th", ascending=False)[:10]
top_payingmajors
# Out:
#                                                  Major  \
# 59                               PETROLEUM ENGINEERING
# 97                    MATHEMATICS AND COMPUTER SCIENCE
# 58                                 NUCLEAR ENGINEERING
# 154  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 51              GEOLOGICAL AND GEOPHYSICAL ENGINEERING
# 57           NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 56                      MINING AND MINERAL ENGINEERING
# 55                           METALLURGICAL ENGINEERING
# 45                                CHEMICAL ENGINEERING
# 48                              ELECTRICAL ENGINEERING
#
#               Major_category   Total  Employed  Unemployed  Unemployment_rate  \
# 59               Engineering   19631     14002         617           0.042205
# 97   Computers & Mathematics    7184      5874         150           0.024900
# 58               Engineering    9826      7320         527           0.067159
# ...

# %% [markdown]
# ### 4. Plot the data from the last question in a bar chart, include proper title, and labels

# %%
top_payingmajors
w = .4
plt.figure(figsize=(20, 12))
plt.bar(x=top_payingmajors.Major.tolist(), width = w, height = top_payingmajors.P75th.tolist(), align = "center")
plt.xlabel("Top paying majors")
plt.ylabel("Average salary")
plt.show()

# %% [markdown]
# ### 6. Visualize only the top 5 paying major categories

# %%
majors.groupby("Major_category")["P75th"].mean().sort_values(ascending=False).head(5)
# Out:
# Major_category
# Engineering                        108534.482759
# Computers & Mathematics             95818.181818
# Physical Sciences                   92000.000000
# Business                            91461.538462
# Agriculture & Natural Resources     81300.000000
# Name: P75th, dtype: float64

# %%
majors.groupby("Major_category")["P75th"].mean().sort_values(ascending=False).head().plot(kind="bar", figsize=(12,10), title = "Top 5 paying major categories")
plt.show()

# %% [markdown]
# ### 7. Plot a histogram of the distribution of median salaries

# %%
sns.distplot(majors.Median);

# %% [markdown]
# ### 8. Plot a histogram of the distribution of median salaries by major category

# %%
sns.distplot(majors.groupby("Major_category")["Median"].mean());
plt.xlabel("by major category")
plt.ylabel("Median salary")
plt.show()

# %%
majors.groupby("Major_category")["Median"].mean().sort_values(ascending=False)
# Out:
# Major_category
# Engineering                            77758.620690
# Computers & Mathematics                66272.727273
# Physical Sciences                      62400.000000
# Business                               60615.384615
# Health                                 56458.333333
# Agriculture & Natural Resources        55000.000000
# Social Science                         53222.222222
# Law & Public Policy                    52800.000000
# Industrial Arts & Consumer Services    52642.857143
# Biology & Life Science                 50821.428571
# Communications & Journalism            49500.000000
# Humanities & Liberal Arts              46080.000000
# Psychology & Social Work               44555.555556
# Education                              43831.250000
# Arts                                   43525.000000
# Interdisciplinary                      43000.000000
# Name: Median, dtype: float64

# %% [markdown]
# ### 9. What are the top 10 most UNemployed majors?

# %%
majors.sort_values(["Unemployed"], ascending=False).Major.tolist()[:10]
# Out:
# ['BUSINESS MANAGEMENT AND ADMINISTRATION',
#  'GENERAL BUSINESS',
#  'PSYCHOLOGY',
#  'ACCOUNTING',
#  'COMMUNICATIONS',
#  'ENGLISH LANGUAGE AND LITERATURE',
#  'MARKETING AND MARKETING RESEARCH',
#  'POLITICAL SCIENCE AND GOVERNMENT',
#  'GENERAL EDUCATION',
#  'BIOLOGY']

# %% [markdown]
# ### 10. What are the top 10 most UNemployed majors CATEGORIES? Use the mean for each category

# %%
majors.groupby("Major_category")["Unemployed"].mean().sort_values(ascending=False).head(10)
# Out:
# Major_category
# Business                       33415.153846
# Communications & Journalism    25299.750000
# Social Science                 14683.333333
# Arts                           13015.625000
# Humanities & Liberal Arts      11942.400000
# Psychology & Social Work       11578.444444
# Law & Public Policy             8609.800000
# Education                       7833.500000
# Computers & Mathematics         7270.363636
# Health                          6251.083333
# Name: Unemployed, dtype: float64

# %%
##Section 3: College Majors

# %%
fifa = pd.read_csv('../data/fifa_data.csv')
fifa.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# ...

# %% [markdown]
# ### 1. Clean up the dataset.
#
#     - Lowercase the column names
#     - Set the "name" column as the index
#     - Drop the following columns "national_position", "national_kit", "club_kit", "club_joining", and "contract_expiry"
#     - Get rid of all players who are goalkeepers and drop every column that starts with GK
#     - Drop every player whose rating is less than 70
#     - Convert the "height" and "weight" columns to float types
#     - Check to see if there any nulls, if so drop them from the dataset

# %%
fifa.columns =fifa.columns.str.lower()

# %%
fifa.set_index("name", inplace = True)

# %%
fifa.drop(["national_position", "national_kit", "club_kit", "club_joining", "contract_expiry"], axis=1, inplace = True)

# %%
fifa.drop(["club_position" == "GK"], axis = 0, inplace = True)

# %%
fifa.drop(["gk_positioning", "gk_diving", "gk_kicking", "gk_handling", "gk_reflexes"], axis = 1, inplace = True)

# %%
fifa.drop(fifa["rating"] < 70, axis = 0, inplace = True)

# %%
fifa["height"] = fifa.height.str.replace("cm", "")

# %%
fifa["weight"] = fifa.height.str.replace("kg", "")

# %%
fifa.height = fifa.height.astype(float)
fifa.weight = fifa.weight.astype(float)

# %%
fifa.height.dtype
# Out:
# dtype('float64')

# %%
fifa.weight.dtype
# Out:
# dtype('float64')

# %%
fifa.isnull().sum()
# Out:
# nationality           0
# club                  0
# club_position         1
# rating                0
# height                0
# weight                0
# preffered_foot        0
# birth_date            0
# age                   0
# preffered_position    0
# work_rate             0
# weak_foot             0
# skill_moves           0
# ball_control          0
# dribbling             0
# marking               0
# sliding_tackle        0
# standing_tackle       0
# aggression            0
# reactions             0
# attacking_position    0
# interceptions         0
# vision                0
# composure             0
# crossing              0
# short_pass            0
# long_pass             0
# acceleration          0
# speed                 0
# stamina               0
# strength              0
# balance               0
# agility               0
# jumping               0
# heading               0
# shot_power            0
# finishing             0
# long_shots            0
# ...

# %%
fifa.dropna(inplace=True)

# %% [markdown]
# ### 2.  Who are the top five players of the following attributes: speed, marking, and finishing

# %%
fifa.head()
# Out:
#                   nationality          club club_position  rating  height  \
# name
# Cristiano Ronaldo    Portugal   Real Madrid            LW      94   185.0
# Lionel Messi        Argentina  FC Barcelona            RW      93   170.0
# Neymar                 Brazil  FC Barcelona            LW      92   174.0
# Luis Suárez           Uruguay  FC Barcelona            ST      92   182.0
# Manuel Neuer          Germany     FC Bayern            GK      92   193.0
#
#                    weight preffered_foot  birth_date  age preffered_position  \
# name
# Cristiano Ronaldo   185.0          Right  02/05/1985   32              LW/ST
# Lionel Messi        170.0           Left  06/24/1987   29                 RW
# Neymar              174.0          Right  02/05/1992   25                 LW
# Luis Suárez         182.0          Right  01/24/1987   30                 ST
# Manuel Neuer        193.0          Right  03/27/1986   31                 GK
#
# ...

# %%
#call the columns
fifa.columns
# Out:
# Index(['nationality', 'club', 'club_position', 'rating', 'height', 'weight',
#        'preffered_foot', 'birth_date', 'age', 'preffered_position',
#        'work_rate', 'weak_foot', 'skill_moves', 'ball_control', 'dribbling',
#        'marking', 'sliding_tackle', 'standing_tackle', 'aggression',
#        'reactions', 'attacking_position', 'interceptions', 'vision',
#        'composure', 'crossing', 'short_pass', 'long_pass', 'acceleration',
#        'speed', 'stamina', 'strength', 'balance', 'agility', 'jumping',
#        'heading', 'shot_power', 'finishing', 'long_shots', 'curve',
#        'freekick_accuracy', 'penalties', 'volleys'],
#       dtype='object')

# %%
#top five players for speed
fifa.sort_values(by = "speed").head()
# Out:
#                    nationality             club club_position  rating  height  \
# name
# Horacio Ramírez      Argentina          Quilmes           Sub      61   186.0
# Miłosz Mleczko          Poland      Lech Poznań           Sub      53   191.0
# Chris Day              England        Stevenage            GK      59   188.0
# Kazushige Kirihata       Japan   Kashiwa Reysol           Sub      62   187.0
# Daniel Andersson        Sweden  Helsingborgs IF           Sub      57   187.0
#
#                     weight preffered_foot  birth_date  age preffered_position  \
# name
# Horacio Ramírez      186.0          Right  03/21/1984   33                 GK
# Miłosz Mleczko       191.0          Right  03/01/1999   18                 GK
# Chris Day            188.0          Right  07/28/1975   41                 GK
# Kazushige Kirihata   187.0          Right  06/30/1987   29                 GK
# Daniel Andersson     187.0          Right  12/18/1972   44                 GK
#
# ...

# %%
#top five players for marking
fifa.sort_values(by = "marking").head()
# Out:
#                      nationality             club club_position  rating  \
# name
# Diego Figueroa             Chile        Wanderers           Res      57
# Callum Stanton           England      Bournemouth           Res      54
# Peter Vindahl Jensen     Denmark  FC Nordsjælland           Res      51
# Dani Hernández         Venezuela      CD Tenerife            GK      74
# Yerko Urra                 Chile    CD Huachipato           Sub      56
#
#                       height  weight preffered_foot  birth_date  age  \
# name
# Diego Figueroa         181.0   181.0          Right  02/21/1990   27
# Callum Stanton         185.0   185.0          Right  01/02/1998   19
# Peter Vindahl Jensen   194.0   194.0          Right  02/16/1998   19
# Dani Hernández         196.0   196.0          Right  10/21/1985   31
# Yerko Urra             189.0   189.0          Right  07/09/1996   20
#
#                      preffered_position   ...    agility  jumping  heading  \
# ...

# %%
#top five players for finishing
fifa.sort_values(by = "finishing").head()
# Out:
#                     nationality             club club_position  rating  \
# name
# Louis Bostyn            Belgium    Zulte-Waregem           Sub      62
# Alexandre Bouchard       France   Cham. Niortais           Sub      60
# Tarjei Aase Omenås       Norway          Sogndal           Sub      52
# Theo Zwarthoed      Netherlands  Go Ahead Eagles            GK      66
# Dorian Grange            France   Olym. Lyonnais           Res      54
#
#                     height  weight preffered_foot  birth_date  age  \
# name
# Louis Bostyn         195.0   195.0          Right  10/04/1993   23
# Alexandre Bouchard   182.0   182.0          Right  05/01/1988   28
# Tarjei Aase Omenås   188.0   188.0          Right  02/02/1992   25
# Theo Zwarthoed       188.0   188.0          Right  11/19/1982   34
# Dorian Grange        184.0   184.0          Right  05/10/1996   20
#
#                    preffered_position   ...    agility  jumping  heading  \
# name                                    ...
# ...

# %% [markdown]
# ### 3. Who is the tallest French lefted foot player?

# %%
max_height = fifa[(fifa.nationality == "France") & (fifa.preffered_foot == "Left")]["height"].max()
print (max_height)
# Out:
# 197.0

# %%
max_height = fifa[(fifa.nationality == "France") & (fifa.preffered_foot == "Left")]["height"].max()

fifa[(fifa.nationality == "France") & (fifa.preffered_foot == "Left") & (fifa.height == max_height)]
# Out:
#             nationality            club club_position  rating  height  weight  \
# name
# Lucas Mocio      France  Olym. Lyonnais           Sub      63   197.0   197.0
#
#             preffered_foot  birth_date  age preffered_position   ...     \
# name                                                             ...
# Lucas Mocio           Left  05/11/1994   22                 GK   ...
#
#             agility  jumping  heading  shot_power  finishing  long_shots  \
# name
# Lucas Mocio      39       63       17          23         21          15
#
#              curve  freekick_accuracy  penalties  volleys
# name
# Lucas Mocio     19                 12         17       20
#
# [1 rows x 42 columns]

# %% [markdown]
# ### 4. Show a pandas series of every attribute's correlation with the rating attribute

# %%
fifa.corr()["rating"]
# Out:
# rating                1.000000
# height                0.046937
# weight                0.046937
# age                   0.458098
# weak_foot             0.226263
# skill_moves           0.251926
# ball_control          0.463211
# dribbling             0.368565
# marking               0.236843
# sliding_tackle        0.215385
# standing_tackle       0.249156
# aggression            0.404422
# reactions             0.828329
# attacking_position    0.354501
# interceptions         0.319504
# vision                0.489277
# composure             0.613612
# crossing              0.401851
# short_pass            0.496239
# long_pass             0.483217
# acceleration          0.206392
# speed                 0.224253
# stamina               0.355335
# strength              0.369045
# balance               0.087811
# agility               0.283309
# jumping               0.289840
# heading               0.343265
# shot_power            0.441773
# finishing             0.328576
# ...

# %% [markdown]
# ### 5. Make a heatmap of the dataset's correlation table

# %%
sns.heatmap(fifa.corr());

# %% [markdown]
# ### 6. Return a dataframe with only players from the following clubs. Call the dataframe fifa2. From now on we'll be using fifa2

# %%
clubs_list = ['Real Madrid', 'FC Barcelona', 'FC Bayern', 'Manchester Utd',
       'Chelsea', 'Arsenal', 'Juventus', 'PSG', 'Manchester City',
              'Bor. Dortmund', 'Liverpool', 'Roma']

# %%
df = pd.DataFrame(fifa)

# %%
fifa2 = df.loc[df['club'].isin(clubs_list)]

# %%
fifa2.head()
# Out:
#                   nationality          club club_position  rating  height  \
# name
# Cristiano Ronaldo    Portugal   Real Madrid            LW      94   185.0
# Lionel Messi        Argentina  FC Barcelona            RW      93   170.0
# Neymar                 Brazil  FC Barcelona            LW      92   174.0
# Luis Suárez           Uruguay  FC Barcelona            ST      92   182.0
# Manuel Neuer          Germany     FC Bayern            GK      92   193.0
#
#                    weight preffered_foot  birth_date  age preffered_position  \
# name
# Cristiano Ronaldo   185.0          Right  02/05/1985   32              LW/ST
# Lionel Messi        170.0           Left  06/24/1987   29                 RW
# Neymar              174.0          Right  02/05/1992   25                 LW
# Luis Suárez         182.0          Right  01/24/1987   30                 ST
# Manuel Neuer        193.0          Right  03/27/1986   31                 GK
#
# ...

# %% [markdown]
# ### 7. Make a bar plot of the average long_shots, curve, and dribbling attributes of the clubs in the data

# %%
#List of long_shots, curve, and dribbling attributes columns  
cols = ["long_shots", "curve", "dribbling"]

# %%
#Group by clubs
#Pass in cols
#Call .mean()
#Call .plot() with bar plot and size of 10x8
fifa2.groupby("club")[cols].mean().plot(kind="bar", figsize=(12,10), title = "average by club")
plt.show()

# %% [markdown]
# ### 8. Make a scatter plot of short_pass vs marking and use the preffered_foot column to color-encode the dots.

# %%
#Create color dictionary, which we'll use to map over the pandas series. 
#Convert "Right" preffered_foot to yellow and "Left" preffered_foot to green
color_dict = {"Right":"y", "Left":"g"}

#Create new pandas series object which is the legendary column but with color-encoding
colors = fifa2.preffered_foot.map(color_dict)

#Scatter with new color encoding
fifa2.plot(x="short_pass", y = "marking", kind="scatter", c = colors, figsize= (10, 8))
plt.show()

# %% [markdown]
# ### 9. Make a grouped boxplots using club_position as the x axis for the following attributes: dribbling, balance, and sliding_tackle

# %%
fifa2.club_position.unique()
# Out:
# array(['LW', 'RW', 'ST', 'GK', 'Sub', 'RCM', 'CAM', 'LCB', 'LCM', 'RB',
#        'RCB', 'LM', 'LDM', 'RM', 'LB', 'CDM', 'RDM', 'LF', 'CB', 'RF',
#        'Res', 'LWB', 'RWB'], dtype=object)

# %%
#Dribbling boxplot
sns.boxplot(x= "club_position", y = "dribbling", data = fifa2);

# %% [markdown]
# Which position is better at dribbling? ST or RCM? Why?

# %%
# ST is better at dribbling as RCM as boxplot for ST is higher and more ogter above 80

# %%
#Balance boxplot
sns.boxplot(x= "club_position", y = "balance", data = fifa2);

# %% [markdown]
# Which position is better at balance? LM or LDM? Why?

# %%
#LM is better at balance as the values and the mean are higher

# %%
#sliding_tackle boxplot
sns.boxplot(x= "club_position", y = "sliding_tackle", data = fifa2);

# %% [markdown]
# What is the IQR for positions ST, RB, and RM?

# %%
#IQR for ST = 35-17=18
#IQR for RB = 90-80=10
#IQR for RM = 75-45=30
